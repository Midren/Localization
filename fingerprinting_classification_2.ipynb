# %%
import numpy as np
import pandas as pd

# %%
# df = pd.read_csv('./data/fingerprinting_2.csv', index_col='Unnamed: 0')
df = pd.read_csv('./data/fingerprinting_2/fingerprinting.csv', index_col='Unnamed: 0')
df = df.reset_index(drop=True)

# %%
df
# Out:
#        Server-RSSI-1  Server-RSSI-2  Server-RSSI-3  Server-RSSI-4  \
# 0                -55            -71            -69            -57
# 1                -57            -64            -58            -48
# 2                -57            -64            -58            -48
# 3                -57            -64            -57            -48
# 4                -57            -65            -57            -48
# ...              ...            ...            ...            ...
# 47795            -63            -51            -58            -52
# 47796            -63            -51            -58            -52
# 47797            -62            -51            -58            -52
# 47798            -63            -51            -58            -52
# 47799            -63            -51            -58            -52
#
#        Server-RSSI-5 Square  Point  Orientation
# 0                -58     s0      0          0.0
# 1                -58     s0      0          0.0
# ...

# %%
grouped = df.groupby(["Square"])

for i in range(12):
    print(len(grouped.get_group("s" + str(i))["Point"]))
# Out:
# 4000
# 3900
# 3900
# 4000
# 4000
# 4000
# 4000
# 4000
# 4000
# 4000
# 4000
# 4000
